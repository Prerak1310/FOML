# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerak1310/FOML/blob/main/DecisionTree(Weather).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####<mark> dataset </marK>

# %%
import pandas as pd
weather_dataset = pd.read_csv('/content/dataset.csv')
weather_dataset
# Out:
#      outlook humidity   windy play
# 0      sunny     high    weak   no
# 1      sunny     high  strong   no
# 2   overcast     high    weak  yes
# 3      rainy     high    weak  yes
# 4      rainy  normal     weak  yes
# 5      rainy  normal   strong   no
# 6   overcast  normal     weak  yes
# 7      sunny     high    weak   no
# 8      sunny  normal     weak  yes
# 9      rainy  normal     weak  yes
# 10     sunny  normal   strong  yes
# 11  overcast     high  strong  yes
# 12  overcast  normal     weak  yes
# 13     rainy     high  strong   no

# %% [markdown]
# ####<mark>LabelEncoding</mark>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
weather_dataset=weather_dataset.apply(le.fit_transform)

weather_dataset
# Out:
#     outlook  humidity  windy  play
# 0         2         0      1     0
# 1         2         0      0     0
# 2         0         0      1     1
# 3         1         0      1     1
# 4         1         1      1     1
# 5         1         1      0     0
# 6         0         1      1     1
# 7         2         0      1     0
# 8         2         1      1     1
# 9         1         1      1     1
# 10        2         1      0     1
# 11        0         0      0     1
# 12        0         1      1     1
# 13        1         0      0     0
