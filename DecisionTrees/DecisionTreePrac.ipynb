# %%
import pandas as pd
dataset = pd.read_csv("/content/Purchase_new.csv")
dataset
# Out:
#    Holiday Discount Free Delivery Purchase
# 0       No      Yes           Yes      Yes
# 1       No      Yes           Yes      Yes
# 2       No       No            No       No
# 3      yes      Yes           Yes      Yes
# 4      yes      Yes           Yes      Yes
# 5      yes       No            No       No
# 6      yes      Yes            No      Yes
# 7       No      Yes           Yes      Yes
# 8      yes      Yes           Yes      Yes
# 9      yes      Yes           Yes      Yes
# 10     yes       No           Yes      Yes
# 11     yes       No            No       No
# 12     yes      Yes           Yes      Yes
# 13     yes      Yes           Yes      Yes
# 14     yes      Yes           Yes      Yes
# 15      No      Yes           Yes      Yes
# 16     yes       No           Yes      Yes
# 17      No      Yes            No      Yes
# 18     yes       No            No      Yes
# 19     yes       No           Yes      Yes
# 20      No      Yes           Yes      Yes
# 21     yes      Yes           Yes       No
# 22     yes       No           Yes      Yes
# 23      No      Yes           Yes      Yes
# 24     yes       No            No       No
# 25      No       No           Yes       No
# 26      No      Yes           Yes      Yes
# 27      No      Yes           Yes      Yes
# 28     yes      Yes           Yes      Yes
# 29     yes      Yes           Yes      Yes

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset = dataset.apply(le.fit_transform)
dataset
# Out:
#     Holiday  Discount  Free Delivery  Purchase
# 0         0         1              1         1
# 1         0         1              1         1
# 2         0         0              0         0
# 3         1         1              1         1
# 4         1         1              1         1
# 5         1         0              0         0
# 6         1         1              0         1
# 7         0         1              1         1
# 8         1         1              1         1
# 9         1         1              1         1
# 10        1         0              1         1
# 11        1         0              0         0
# 12        1         1              1         1
# 13        1         1              1         1
# 14        1         1              1         1
# 15        0         1              1         1
# 16        1         0              1         1
# 17        0         1              0         1
# 18        1         0              0         1
# 19        1         0              1         1
# 20        0         1              1         1
# 21        1         1              1         0
# 22        1         0              1         1
# 23        0         1              1         1
# 24        1         0              0         0
# 25        0         0              1         0
# 26        0         1              1         1
# 27        0         1              1         1
# 28        1         1              1         1
# 29        1         1              1         1

# %%
features = ['Holiday' , 'Discount' , 'Free Delivery']
X = dataset[features]
y = dataset['Purchase']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split( X , y , test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'gini')
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import numpy as np
predicted_values = classifier.predict(X_test)
predicted_values
# Out:
# array([0, 1, 0, 1, 0, 1])

# %%
classifier.score(X_test,y_test)
# Out:
# 0.8333333333333334
